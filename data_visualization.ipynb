# %%
import pandas as pd

# %%
movies_data = pd.read_csv("https://raw.githubusercontent.com/andandandand/CSV-datasets/master/tmdb_5000_credits.csv")
movies_data
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.shape
# Out:
# (4803, 4)

# %%
movies_data.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movies_data.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
movies_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_data.tail(15)
# Out:
#       movie_id                         title  \
# 4788       692                Pink Flamingos
# 4789     39851                         Clean
# 4790     13898                    The Circle
# 4791    157185                   Tin Can Man
# 4792     36095                          Cure
# 4793    182291                On The Downlow
# 4794    286939  Sanctuary: Quite a Conundrum
# 4795    124606                          Bang
# 4796     14337                        Primer
# 4797     67238                        Cavite
# 4798      9367                   El Mariachi
# 4799     72766                     Newlyweds
# 4800    231617     Signed, Sealed, Delivered
# 4801    126186              Shanghai Calling
# 4802     25975             My Date with Drew
#
#                                                    cast  \
# 4788  [{"cast_id": 8, "character": "Divine / Babs Jo...
# 4789  [{"cast_id": 1, "character": "Emily Wang", "cr...
# 4790  [{"cast_id": 3, "character": "Nargess", "credi...
# ...

# %%
movies_data.head(30)
# Out:
#     movie_id                                        title  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# ...

# %%
movies_data.tail()
# Out:
#       movie_id                      title  \
# 4798      9367                El Mariachi
# 4799     72766                  Newlyweds
# 4800    231617  Signed, Sealed, Delivered
# 4801    126186           Shanghai Calling
# 4802     25975          My Date with Drew
#
#                                                    cast  \
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
movies_data.describe()
# Out:
#             movie_id
# count    4803.000000
# mean    57165.484281
# std     88694.614033
# min         5.000000
# 25%      9014.500000
# 50%     14629.000000
# 75%     58610.500000
# max    459488.000000

# %%
movies_data['title']# series made ahe
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: title, Length: 4803, dtype: object

# %%
movies_data[['title']]# dataframe made ahe
# Out:
#                                          title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
# [4803 rows x 1 columns]

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies_data[['title']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data[['movie_id','title']]
# Out:
#       movie_id                                     title
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
# [4803 rows x 2 columns]

# %%
type(movies_data[['movie_id','title']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.columns.size
# Out:
# 4

# %%
movies_data[0:2]
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies_data[2:5]
# Out:
#    movie_id                  title  \
# 2    206647                Spectre
# 3     49026  The Dark Knight Rises
# 4     49529            John Carter
#
#                                                 cast  \
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies_data.iloc[[1]]
# Out:
#    movie_id                                     title  \
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
type(movies_data.iloc[1])
# Out:
# pandas.core.series.Series

# %%
movies_data.iloc[0:7] # it exclued last no in given range
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# 5  [{"cast_id": 30, "character": "Peter Parker / ...
# 6  [{"cast_id": 34, "character": "Flynn Rider (vo...
#
#                                                 crew
# ...

# %%
movies_data.loc[0:7] # it akes all goven value in range in braket
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# 5  [{"cast_id": 30, "character": "Peter Parker / ...
# 6  [{"cast_id": 34, "character": "Flynn Rider (vo...
# ...

# %%
type(movies_data.iloc[0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.loc[[0,5,10,15,20,25,26,30,31,33]]
# Out:
#     movie_id                                     title  \
# 0      19995                                    Avatar
# 5        559                              Spider-Man 3
# 10      1452                          Superman Returns
# 15      2454  The Chronicles of Narnia: Prince Caspian
# 20      1930                    The Amazing Spider-Man
# 25       597                                   Titanic
# 26    271110                Captain America: Civil War
# 30       558                              Spider-Man 2
# 31     68721                                Iron Man 3
# 33     36668                     X-Men: The Last Stand
#
#                                                  cast  \
# 0   [{"cast_id": 242, "character": "Jake Sully", "...
# 5   [{"cast_id": 30, "character": "Peter Parker / ...
# 10  [{"cast_id": 3, "character": "Superman / Clark...
# 15  [{"cast_id": 1, "character": "Prince Caspian",...
# 20  [{"cast_id": 56, "character": "Peter Parker / ...
# ...

# %%
movies_data.iloc[[0,5,10,15],[1,3]]
# Out:
#                                        title  \
# 0                                     Avatar
# 5                               Spider-Man 3
# 10                          Superman Returns
# 15  The Chronicles of Narnia: Prince Caspian
#
#                                                  crew
# 0   [{"credit_id": "52fe48009251416c750aca23", "de...
# 5   [{"credit_id": "52fe4252c3a36847f80151a5", "de...
# 10  [{"credit_id": "553bef6a9251416874003c8f", "de...
# 15  [{"credit_id": "55a239e69251412979002e8b", "de...

# %%
movies_data.iloc[[0,5,10,15],0:7]
# Out:
#     movie_id                                     title  \
# 0      19995                                    Avatar
# 5        559                              Spider-Man 3
# 10      1452                          Superman Returns
# 15      2454  The Chronicles of Narnia: Prince Caspian
#
#                                                  cast  \
# 0   [{"cast_id": 242, "character": "Jake Sully", "...
# 5   [{"cast_id": 30, "character": "Peter Parker / ...
# 10  [{"cast_id": 3, "character": "Superman / Clark...
# 15  [{"cast_id": 1, "character": "Prince Caspian",...
#
#                                                  crew
# 0   [{"credit_id": "52fe48009251416c750aca23", "de...
# 5   [{"credit_id": "52fe4252c3a36847f80151a5", "de...
# 10  [{"credit_id": "553bef6a9251416874003c8f", "de...
# 15  [{"credit_id": "55a239e69251412979002e8b", "de...

# %%
movies_data.iloc[[0,5,10,15],0:3]
# Out:
#     movie_id                                     title  \
# 0      19995                                    Avatar
# 5        559                              Spider-Man 3
# 10      1452                          Superman Returns
# 15      2454  The Chronicles of Narnia: Prince Caspian
#
#                                                  cast
# 0   [{"cast_id": 242, "character": "Jake Sully", "...
# 5   [{"cast_id": 30, "character": "Peter Parker / ...
# 10  [{"cast_id": 3, "character": "Superman / Clark...
# 15  [{"cast_id": 1, "character": "Prince Caspian",...

# %%
movies_data.iloc[[0,5,10,15,20,21,25], :5]
# Out:
#     movie_id                                     title  \
# 0      19995                                    Avatar
# 5        559                              Spider-Man 3
# 10      1452                          Superman Returns
# 15      2454  The Chronicles of Narnia: Prince Caspian
# 20      1930                    The Amazing Spider-Man
# 21     20662                                Robin Hood
# 25       597                                   Titanic
#
#                                                  cast  \
# 0   [{"cast_id": 242, "character": "Jake Sully", "...
# 5   [{"cast_id": 30, "character": "Peter Parker / ...
# 10  [{"cast_id": 3, "character": "Superman / Clark...
# 15  [{"cast_id": 1, "character": "Prince Caspian",...
# 20  [{"cast_id": 56, "character": "Peter Parker / ...
# 21  [{"cast_id": 1, "character": "Robin Longstride...
# 25  [{"cast_id": 20, "character": "Rose DeWitt Buk...
#
#                                                  crew
# ...

# %%
import pandas as pd

# %%
movies_data = pd.read_csv("tmdb_5000_credits.csv")
movies_data
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies_data.iloc[[0,5,10,15,20,25], 1:2]
# Out:
#                                        title
# 0                                     Avatar
# 5                               Spider-Man 3
# 10                          Superman Returns
# 15  The Chronicles of Narnia: Prince Caspian
# 20                    The Amazing Spider-Man
# 25                                   Titanic

# %%
movies_data.iloc[[30]]
# Out:
#     movie_id         title                                               cast  \
# 30       558  Spider-Man 2  [{"cast_id": 33, "character": "Peter Parker / ...
#
#                                                  crew
# 30  [{"credit_id": "52fe4252c3a36847f8015039", "de...

# %%
movies_data.iloc[0:3]
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
movies_data.loc[0:4] # diffence between iloc and loc is inculed and exclued
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# # to change index as tittle

# %%
movies_data = pd.read_csv("tmdb_5000_credits.csv",index_col = 'title')
movies_data
# Out:
#                                           movie_id  \
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
# ...                                            ...
# El Mariachi                                   9367
# Newlyweds                                    72766
# Signed, Sealed, Delivered                   231617
# Shanghai Calling                            126186
# My Date with Drew                            25975
#
#                                                                                        cast  \
# title
# Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# ...

# %%
movies_data.loc[['Avatar']]
# Out:
#         movie_id                                               cast  \
# title
# Avatar     19995  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                      crew
# title
# Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies_data.loc[['Spectre','Avatar']]
# Out:
#          movie_id                                               cast  \
# title
# Spectre    206647  [{"cast_id": 1, "character": "James Bond", "cr...
# Avatar      19995  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                       crew
# title
# Spectre  [{"credit_id": "54805967c3a36829b5002c41", "de...
# Avatar   [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies_data.loc[['Spectre','Avatar','John Carter'],['cast','crew']]
# Out:
#                                                           cast  \
# title
# Spectre      [{"cast_id": 1, "character": "James Bond", "cr...
# Avatar       [{"cast_id": 242, "character": "Jake Sully", "...
# John Carter  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                           crew
# title
# Spectre      [{"credit_id": "54805967c3a36829b5002c41", "de...
# Avatar       [{"credit_id": "52fe48009251416c750aca23", "de...
# John Carter  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
ser = movies_data[['cast']]
ser
# Out:
#                                                                                        cast
# title
# Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# Spectre                                   [{"cast_id": 1, "character": "James Bond", "cr...
# The Dark Knight Rises                     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# John Carter                               [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                                                     ...
# El Mariachi                               [{"cast_id": 1, "character": "El Mariachi", "c...
# Newlyweds                                 [{"cast_id": 1, "character": "Buzzy", "credit_...
# Signed, Sealed, Delivered                 [{"cast_id": 8, "character": "Oliver O\u2019To...
# ...

# %%
ser.size
# Out:
# 4803

# %%
ser.describe()
# Out:
#         cast
# count   4803
# unique  4761
# top       []
# freq      43

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, Avatar to My Date with Drew
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   cast      4803 non-null   object
#  2   crew      4803 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 279.1+ KB

# %%
ser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, Avatar to My Date with Drew
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    4803 non-null   object
# dtypes: object(1)
# memory usage: 204.1+ KB

# %%
ser.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled',
#        'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince',
#        'Batman v Superman: Dawn of Justice',
#        ...
#        'On The Downlow', 'Sanctuary: Quite a Conundrum', 'Bang', 'Primer',
#        'Cavite', 'El Mariachi', 'Newlyweds', 'Signed, Sealed, Delivered',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='title', length=4803)

# %%
ser = movies_data['movie_id']
ser
# Out:
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
#                                              ...
# El Mariachi                                   9367
# Newlyweds                                    72766
# Signed, Sealed, Delivered                   231617
# Shanghai Calling                            126186
# My Date with Drew                            25975
# Name: movie_id, Length: 4803, dtype: int64

# %%
ser.head()
# Out:
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
# The Dark Knight Rises                        49026
# John Carter                                  49529
# Name: movie_id, dtype: int64

# %%
ser.sum()
# Out:
# 274565821

# %%
ser.size
# Out:
# 4803

# %%
ser.count()
# Out:
# 4803

# %%
ser.mean()
# Out:
# 57165.484280657925

# %%
ser.std()
# Out:
# 88694.61403331814

# %%
ser.median()
# Out:
# 14629.0

# %%
ser.describe()
# Out:
# count      4803.000000
# mean      57165.484281
# std       88694.614033
# min           5.000000
# 25%        9014.500000
# 50%       14629.000000
# 75%       58610.500000
# max      459488.000000
# Name: movie_id, dtype: float64

# %%
ser.min()
# Out:
# 5

# %%
ser.max()
# Out:
# 459488

# %%
ser.unique()
# Out:
# array([ 19995,    285, 206647, ..., 231617, 126186,  25975], dtype=int64)

# %%
len(ser.unique())
# Out:
# 4803

# %%
ser.value_counts()
# Out:
# 19995     1
# 333355    1
# 71157     1
# 43418     1
# 11588     1
#          ..
# 13156     1
# 293863    1
# 16871     1
# 307081    1
# 25975     1
# Name: movie_id, Length: 4803, dtype: int64
